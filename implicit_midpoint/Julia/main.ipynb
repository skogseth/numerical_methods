# %% [markdown]
# # Setup

# %%
using Plots

# %%
include("src/implicit_midpoint.jl");

# %% [markdown]
# # Calculation

# %%
f(t,y) = -0.8 * y;
t, y = implicit_midpoint(0., 10., 0.5, f);
y_sol = y[1] * exp.(-0.8*t);

# %% [markdown]
# # Plotting

# %%
plt = plot()
plt = plot!(t, y)
plt = plot!(t, y_sol)
